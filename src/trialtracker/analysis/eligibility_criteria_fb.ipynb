# %%
# set path
import os
import sys
my_path = os.path.abspath(os.path.dirname('.'))
path = os.path.join(my_path, "..")
sys.path.insert(1, path)

# %%
# load modules
import pandas as pd
from extract import extracted_data_analyzer as eda, aact_querier as aq
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import psycopg2
import getpass
import pandas.io.sql as psql
import plotly.express as px
import imageio
import pycountry as pc
from plotly.offline import iplot
from matplotlib.pyplot import *
import re

# %%
#configs
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
# read data
onc_trials=pd.read_csv(path+"/extract/extracted_data/onc_trials.csv", parse_dates=['start_datetime'], dtype={'eligibility_criteria': str}, index_col=0)

# %%
onc_trials=onc_trials[(onc_trials.start_datetime.dt.year>=2000)&(onc_trials.start_datetime.dt.year<=2021)]
print(f"{onc_trials['nct_id'].nunique()} cancer trials from 2000 to 2021.")
# Out:
# 74643 cancer trials from 2000 to 2021.

# %%
onc_trials['eligibility_criteria'].fillna('', inplace=True)

# %%
onc_trials['elg_crit_char_len']=onc_trials.eligibility_criteria.str.len()
onc_trials['elg_crit_word_len']=onc_trials.eligibility_criteria.str.count(' ').add(1)

# %%
print(f'Total eligibility criteria characters: {onc_trials.elg_crit_char_len.sum():,}')
# Out:
# Total eligibility criteria characters: 167,587,276

# %%
print(f'Total eligibility criteria words: {onc_trials.elg_crit_word_len.sum():,}')
# Out:
# Total eligibility criteria words: 22,671,705

# %%
onc_trials.elg_crit_word_len.mean()
# Out:
# 303.735179454202

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
plt.hist(onc_trials.elg_crit_word_len, bins=50)
plt.gca().set(title='Histogram of Eligiblity Criteria Word Count for Cancer Trials', ylabel='Frequency (# of Trials)', xlabel='# of Words in Eligiblity Criteria');
plt.savefig("./visuals/elg_crit_word_count_hist.png", bbox_inches='tight')

# %%
onc_trials.elg_crit_word_len.describe()
# Out:
# count    74643.000000
# mean       303.735179
# std        317.041958
# min          1.000000
# 25%         80.000000
# 50%        191.000000
# 75%        421.000000
# max       2704.000000
# Name: elg_crit_word_len, dtype: float64

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Eligibility Criteria Word Count for Cancer Trials')
ax1.set_ylabel('# of Words in Eligibility Criteria')
ax1.set_xlabel('')
ax1.boxplot(onc_trials.elg_crit_word_len)
fig1.savefig("./visuals/elg_crit_word_count_boxplot.png", bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Eligibility Criteria Word Count for Cancer Trials (outliers removed)')
ax1.set_ylabel('# of Words in Eligibility Criteria')
ax1.set_xlabel('')
ax1.boxplot(onc_trials.elg_crit_word_len, showfliers=False)
fig1.savefig("./visuals/elg_crit_word_count_boxplot_nooutlier.png", bbox_inches='tight')

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import csv

# %%
import re
from collections import OrderedDict

p = re.compile(r'[^\w\s]+')
onc_trials['criteria_depunct'] = [p.sub(' ', str(x)) for x in onc_trials['eligibility_criteria'].tolist()]
onc_trials['criteria_depunct_tokenized']=onc_trials['criteria_depunct'].apply(lambda x: [item for item in str(x).split()])
onc_trials['criteria_deduped'] = (onc_trials['criteria_depunct'].str.split()
                         .apply(lambda x: OrderedDict.fromkeys(x).keys())
                         .str.join(' '))

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/forrest.xiao/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#find related words
#https://methodmatters.github.io/using-word2vec-to-analyze-word/
stopwords = nltk.corpus.stopwords.words('english')
onc_trials['criteria_unstopped_tokenized']=onc_trials['criteria_depunct'].apply(lambda x: [item for item in str(x).split() if item not in stopwords])
onc_trials['criteria_unstopped_text']=onc_trials['criteria_unstopped_tokenized'].apply(lambda x: ' '.join(word for word in x))

# %%
onc_trials['count']=1
onc_trials.head()
# Out:
#            nct_id                                              title  \
# 0     NCT00000105  Vaccination With Tetanus and KLH to Assess Imm...
# 176   NCT00001938  A Pilot Study of a Protein Profile Test in Ova...
# 455   NCT00002757  TITLE:Less Intensive Therapy for Children With...
# 713   NCT00003070  Enalapril in Treating Heart Damage Patients Wh...
# 1174  NCT00003611  Acitretin in Preventing Skin Cancers in Patien...
#
#       has_us_facility                                         conditions  \
# 0                True                                             Cancer
# 176              True                                   Ovarian Neoplasm
# 455             False                                  Leukemia|Lymphoma
# 713              True  Cardiac Toxicity|Unspecified Childhood Solid T...
# 1174             True                       Non-melanomatous Skin Cancer
#
#                                    eligibility_criteria  start_date  \
# 0     Inclusion Criteria:\n\nPatients must have a di...  2002-07-31
# 176   INCLUSION CRITERIA\n\nAll patients in first cl...  2000-04-24
# 455   DISEASE CHARACTERISTICS:\n\nOne of the followi...  2001-06-30
# 713   DISEASE CHARACTERISTICS: Histologically diagno...  2000-09-30
# 1174  DISEASE CHARACTERISTICS:\n\nSolid organ recipi...  2000-05-31
#
#                                         lead_sponsor  \
# 0     Masonic Cancer Center, University of Minnesota
# 176                  National Cancer Institute (NCI)
# 455                        Children's Oncology Group
# 713                        Children's Oncology Group
# 1174        Alliance for Clinical Trials in Oncology
#
#                                                 summary overall_status  \
# 0     The purpose of this study is to learn how the ...     Terminated
# 176   Every cell in the human body contains hundreds...      Completed
# 455   RATIONALE: Less intensive therapy may attain i...      Completed
# 713   RATIONALE: Drugs used in chemotherapy use diff...      Completed
# 1174  RATIONALE: Chemoprevention therapy is the use ...      Completed
#
#                phase  enrollment enrollment_type      study_type  \
# 0                NaN       112.0          Actual   Observational
# 176              NaN        26.0          Actual   Observational
# 455          Phase 3      1148.0          Actual  Interventional
# 713          Phase 3        13.0          Actual  Interventional
# 1174  Not Applicable       129.0          Actual  Interventional
#
#       number_of_arms  number_of_groups                 why_stopped has_dmc  \
# 0                NaN               3.0  Replaced by another study.    True
# 176              NaN               NaN                         NaN     NaN
# 455              3.0               NaN                         NaN    True
# 713              8.0               NaN                         NaN    True
# 1174             2.0               NaN                         NaN   False
#
#      is_fda_regulated_drug is_fda_regulated_device is_unapproved_device  \
# 0                      NaN                     NaN                  NaN
# 176                  False                   False                  NaN
# 455                    NaN                     NaN                  NaN
# 713                    NaN                     NaN                  NaN
# 1174                   NaN                     NaN                  NaN
#
#       is_ppsd is_us_export start_datetime  start_year       mapped_phase  \
# 0         NaN          NaN     2002-07-31      2002.0         h) Missing
# 176       NaN          NaN     2000-04-24      2000.0         h) Missing
# 455       NaN          NaN     2001-06-30      2001.0         e) Phase 3
# 713       NaN          NaN     2000-09-30      2000.0         e) Phase 3
# 1174      NaN          NaN     2000-05-31      2000.0  g) Not Applicable
#
#       mapped_study_type  elg_crit_char_len  elg_crit_word_len  \
# 0      b) Observational               1182                169
# 176    b) Observational               1186                157
# 455   a) Interventional               1069                117
# 713   a) Interventional               1522                198
# 1174  a) Interventional               1422                175
#
#                                        criteria_depunct  \
# 0     Inclusion Criteria \n\nPatients must have a di...
# 176   INCLUSION CRITERIA\n\nAll patients in first cl...
# 455   DISEASE CHARACTERISTICS \n\nOne of the followi...
# 713   DISEASE CHARACTERISTICS  Histologically diagno...
# 1174  DISEASE CHARACTERISTICS \n\nSolid organ recipi...
#
#                              criteria_depunct_tokenized  \
# 0     [Inclusion, Criteria, Patients, must, have, a,...
# 176   [INCLUSION, CRITERIA, All, patients, in, first...
# 455   [DISEASE, CHARACTERISTICS, One, of, the, follo...
# 713   [DISEASE, CHARACTERISTICS, Histologically, dia...
# 1174  [DISEASE, CHARACTERISTICS, Solid, organ, recip...
#
#                                        criteria_deduped  \
# 0     Inclusion Criteria Patients must have a diagno...
# 176   INCLUSION CRITERIA All patients in first clini...
# 455   DISEASE CHARACTERISTICS One of the following d...
# 713   DISEASE CHARACTERISTICS Histologically diagnos...
# 1174  DISEASE CHARACTERISTICS Solid organ recipient ...
#
#                            criteria_unstopped_tokenized  \
# 0     [Inclusion, Criteria, Patients, must, diagnosi...
# 176   [INCLUSION, CRITERIA, All, patients, first, cl...
# 455   [DISEASE, CHARACTERISTICS, One, following, dia...
# 713   [DISEASE, CHARACTERISTICS, Histologically, dia...
# 1174  [DISEASE, CHARACTERISTICS, Solid, organ, recip...
#
#                                 criteria_unstopped_text  count
# 0     Inclusion Criteria Patients must diagnosis can...      1
# 176   INCLUSION CRITERIA All patients first clinical...      1
# 455   DISEASE CHARACTERISTICS One following diagnose...      1
# 713   DISEASE CHARACTERISTICS Histologically diagnos...      1
# 1174  DISEASE CHARACTERISTICS Solid organ recipient ...      1

# %%
# Create wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
comment_words = ''
# stopwords = set(STOPWORDS)
stopwords = set('')
 
# iterate through the csv file
for val in onc_trials.criteria_depunct:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig("./visuals/elg_crit_cloud.png", bbox_inches='tight')
 
plt.show()

# %%
# Word cloud stopwords removed

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in onc_trials.criteria_unstopped_text:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud_unstopped = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud_unstopped)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig("./visuals/elg_crit_cloud_unstopped.png", bbox_inches='tight')
 
plt.show()

# %%
from collections import defaultdict

num_list = onc_trials['count'].tolist()
text_list = onc_trials['criteria_unstopped_tokenized'].tolist()

# %%
# Get Unigrams
word_freq = defaultdict(lambda: [0, 0]) 

# looping is now over both the text and the numbers
for text, num in zip(text_list, num_list): 
    for word in text: 
        # same as before
        if word !='None':
            word_freq[word][0] += 1
            # new line, incrementing the numeric value for each word
            word_freq[word][1] += float(num)

            
columns = {0: 'trials', 1: 'enrollment_opp'}

# %%
unigrams = pd.DataFrame.from_dict(word_freq, orient='index') \
             .rename(columns=columns) \
             .sort_values('enrollment_opp', ascending=False) \
            .round()

# %%
unigrams.drop('enrollment_opp', axis=1, inplace=True)
unigrams.head(10)
# Out:
#            trials
# study      212832
# 1          198483
# prior      191589
# Patients   165307
# disease    164231
# therapy    161407
# treatment  159463
# within     156313
# must       147706
# 2          143509

# %%
# looping is now over both the text and the numbers
# get bigrams

# default value is now a list with two ints
bigram_freq = defaultdict(lambda: [0, 0]) 

for text, num in zip(text_list, num_list): 
    bgs = nltk.bigrams(text)
    fdist = nltk.FreqDist(bgs)
    for word in fdist: 
        # same as before
        if word !='None':
            bigram_freq[word][0] += 1
            # new line, incrementing the numeric value for each word
            bigram_freq[word][1] += float(num)

# %%
columns = {0: 'frequency', 1: 'enrollment_opp'}

bigrams = pd.DataFrame.from_dict(bigram_freq, orient='index') \
             .rename(columns=columns) \
             .sort_values('frequency', ascending=False) \
            .round()

# %%
bg_dict_sorted = sorted(bigram_freq.items(), key=lambda kv: kv[1], reverse=True)
bg, counts = list(zip(*bg_dict_sorted))
bg_str = list(map(lambda x: ' '.join(x), bg))

# %%
bigrams.drop('enrollment_opp', axis=1, inplace=True)
bigrams.head(15)
# Out:
#                        frequency
# (Inclusion, Criteria)      66520
# (Exclusion, Criteria)      64487
# (informed, consent)        37141
# (18, years)                27257
# (performance, status)      23899
# (1, 5)                     21843
# (6, months)                21531
# (4, weeks)                 18948
# (upper, limit)             18544
# (limit, normal)            18345
# (pregnancy, test)          17985
# (0, 1)                     17689
# (heart, failure)           17544
# (ECOG, performance)        17383
# (3, months)                17167

# %%
bigrams['text']=bigrams.index

# %%
bigrams['Bigram']=bigrams.text.apply(lambda x: ' '.join(x))

# %%
bigrams.head()
# Out:
#                        frequency                   text         concat_text  \
# (Inclusion, Criteria)      66520  (Inclusion, Criteria)  Inclusion Criteria
# (Exclusion, Criteria)      64487  (Exclusion, Criteria)  Exclusion Criteria
# (informed, consent)        37141    (informed, consent)    informed consent
# (18, years)                27257            (18, years)            18 years
# (performance, status)      23899  (performance, status)  performance status
#
#                                    Bigram
# (Inclusion, Criteria)  Inclusion Criteria
# (Exclusion, Criteria)  Exclusion Criteria
# (informed, consent)      informed consent
# (18, years)                      18 years
# (performance, status)  performance status

# %%
bigrams['total_trials']=onc_trials.nct_id.nunique()

# %%
bigrams['rate']=bigrams.frequency/bigrams.total_trials
bigrams.head()
# Out:
#                        frequency                   text         concat_text  \
# (Inclusion, Criteria)      66520  (Inclusion, Criteria)  Inclusion Criteria
# (Exclusion, Criteria)      64487  (Exclusion, Criteria)  Exclusion Criteria
# (informed, consent)        37141    (informed, consent)    informed consent
# (18, years)                27257            (18, years)            18 years
# (performance, status)      23899  (performance, status)  performance status
#
#                                    Bigram  total_trials      rate
# (Inclusion, Criteria)  Inclusion Criteria         74643  0.891175
# (Exclusion, Criteria)  Exclusion Criteria         74643  0.863939
# (informed, consent)      informed consent         74643  0.497582
# (18, years)                      18 years         74643  0.365165
# (performance, status)  performance status         74643  0.320177

# %%
## Setting figure & ax for plots
fig, ax = plt.subplots(figsize=(8.09,5))

## Setting plot to horizontal for easy viewing + setting title + display  
bar_plot = sns.barplot(y=bigrams.iloc[:25].frequency, x=bigrams.iloc[:25]['Bigram'], orient='v', ax=ax)
plt.xticks(rotation=90)
plt.title('Most Common Eligibility Criteria Bigrams')
plt.savefig("./visuals/bigram_barplot.png", bbox_inches='tight')
plt.show();

# %%
# Out:
#        trials  enrollment_opp
# or     905137        905137.0
# of     859412        859412.0
# the    662523        662523.0
# to     503261        503261.0
# and    385997        385997.0
# with   354175        354175.0
# for    270377        270377.0
# a      213279        213279.0
# study  212832        212832.0
# in     211196        211196.0

# %%
# Explore FB extracted data

# %%
ie=pd.read_csv(path+"/extract/extracted_data/ie_parsed_clinical_trials.tsv", sep='\t')
ie_df=ie.merge(onc_trials, how='inner', left_on='#nct_id', right_on='nct_id').iloc[:, 1:36]

# %%
# ie_df=ie.merge(onc_trials, how='inner', left_on='#nct_id', right_on='nct_id').iloc[:, 1:36]

# %%
ie_df.shape
# Out:
# (1669415, 35)

# %%
ie_df['#nct_id'].nunique()
# Out:
# 69004

# %%
ie_df.shape
# Out:
# (1669415, 35)

# %%
onc_trials['nct_id'].nunique()
# Out:
# 74643

# %%
ie_df['#nct_id'].nunique()/onc_trials['nct_id'].nunique()
# Out:
# 0.9244537331029031

# %%
ie_df[~ie_df.concepts.isna()].tail(4)
# Out:
#              #nct_id eligibility_type  \
# 1669403  NCT05420597        exclusion
# 1669406  NCT05420922        inclusion
# 1669410  NCT05421104        inclusion
# 1669412  NCT05421104        inclusion
#
#                                                  criterion  \
# 1669403  Hypersensitivity to Toripalimab, Paclitaxel or...
# 1669406  Clinical diagnosis of hepatocellular carcinoma...
# 1669410  With at least one International Classification...
# 1669412  HCT ≥ 45% with phlebotomy (last phlebotomy wit...
#
#                                  label                      term  ner_score  \
# 1669403          word_scores:pregnancy                  pregnant      0.860
# 1669406             word_scores:cancer  hepatocellular carcinoma      0.980
# 1669410          word_scores:treatment                 treatment      0.757
# 1669412  word_scores:clinical_variable            platelet count      0.968
#
#                           concepts  \
# 1669403                  Pregnancy
# 1669406  Carcinoma, Hepatocellular
# 1669410               Therapeutics
# 1669412             Platelet Count
#
#                                               tree_numbers  nel_score  \
# 1669403                                    G08.686.784.769        1.0
# 1669406  C04.557.470.200.025.255|C04.588.274.623.160|C0...        1.0
# 1669410                                                E02        1.0
# 1669412  E01.370.225.500.195.107.740|E01.370.225.625.10...        1.0
#
#               nct_id                                              title  \
# 1669403  NCT05420597  Induction Chemotherapy and Toripalimab Followe...
# 1669406  NCT05420922  Real-world Study of Efficacy and Safety of ICI...
# 1669410  NCT05421104  Ruxolitinib for Polycythemia Vera in Patients ...
# 1669412  NCT05421104  Ruxolitinib for Polycythemia Vera in Patients ...
#
#          has_us_facility                                         conditions  \
# 1669403            False             Hypopharyngeal Cancer|Laryngeal Cancer
# 1669406            False  Effects of Immunotherapy|Hepatocellular Carcin...
# 1669410             True                             Polycythemia Vera (PV)
# 1669412             True                             Polycythemia Vera (PV)
#
#                                       eligibility_criteria  start_date  \
# 1669403  Inclusion Criteria:\n\nPathologically confirme...  2021-04-07
# 1669406  Inclusion Criteria:\n\nClinical diagnosis of h...  2021-11-01
# 1669410  Inclusion Criteria:\n\nIncluded patients:\n\nW...  2020-11-27
# 1669412  Inclusion Criteria:\n\nIncluded patients:\n\nW...  2020-11-27
#
#                      lead_sponsor  \
# 1669403          Fudan University
# 1669406           Tongji Hospital
# 1669410  Novartis Pharmaceuticals
# 1669412  Novartis Pharmaceuticals
#
#                                                    summary overall_status  \
# 1669403  The aim of this study is to define whether com...     Recruiting
# 1669406  China is a high-risk area of Hepatocellular Ca...     Recruiting
# 1669410  This was an analytical and descriptive, non-in...      Completed
# 1669412  This was an analytical and descriptive, non-in...      Completed
#
#            phase  enrollment enrollment_type      study_type  number_of_arms  \
# 1669403  Phase 2        61.0     Anticipated  Interventional             1.0
# 1669406      NaN      2000.0     Anticipated   Observational             NaN
# 1669410      NaN      1576.0          Actual   Observational             NaN
# 1669412      NaN      1576.0          Actual   Observational             NaN
#
#          number_of_groups why_stopped has_dmc is_fda_regulated_drug  \
# 1669403               NaN         NaN    True                 False
# 1669406               3.0         NaN   False                  True
# 1669410               2.0         NaN     NaN                   NaN
# 1669412               2.0         NaN     NaN                   NaN
#
#         is_fda_regulated_device is_unapproved_device  is_ppsd is_us_export  \
# 1669403                   False                  NaN      NaN          NaN
# 1669406                   False                  NaN      NaN        False
# 1669410                     NaN                  NaN      NaN          NaN
# 1669412                     NaN                  NaN      NaN          NaN
#
#         start_datetime  start_year mapped_phase  mapped_study_type
# 1669403     2021-04-07      2021.0   d) Phase 2  a) Interventional
# 1669406     2021-11-01      2021.0   h) Missing   b) Observational
# 1669410     2020-11-27      2020.0   h) Missing   b) Observational
# 1669412     2020-11-27      2020.0   h) Missing   b) Observational

# %%
type_pie=ie_df.eligibility_type.value_counts().reset_index()
type_pie.columns=['Eligibility Type','Count']
type_pie
# Out:
#   Eligibility Type   Count
# 0        exclusion  941220
# 1        inclusion  728195

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
fig1, ax1 = plt.subplots()
ax1.pie(type_pie['Count'].tolist(), labels=type_pie['Eligibility Type'].tolist(), autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("./visuals/type_pie.png", bbox_inches='tight')

plt.show()

# %%
label_pie=ie_df.label.value_counts().reset_index()
label_pie.columns=['label','count']
label_pie
# Out:
#                                 label   count
# 0               word_scores:treatment  579695
# 1         word_scores:chronic_disease  346037
# 2                  word_scores:cancer  263611
# 3       word_scores:clinical_variable  242707
# 4                  word_scores:gender  105512
# 5               word_scores:pregnancy   65496
# 6   word_scores:contraception_consent   48455
# 7            word_scores:allergy_name   14190
# 8        word_scores:language_fluency    2718
# 9       word_scores:technology_access     945
# 10              word_scores:ethnicity      49

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:


fig1, ax1 = plt.subplots()
ax1.pie(label_pie['count'].tolist(), labels=label_pie['label'].tolist(), autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.savefig("./visuals/label_pie.png", bbox_inches='tight')

plt.show()

# %%
ie_df.head()
# Out:
#        #nct_id eligibility_type  \
# 0  NCT00030264        inclusion
# 1  NCT00030264        inclusion
# 2  NCT00030264        inclusion
# 3  NCT00030264        inclusion
# 4  NCT00030264        inclusion
#
#                                            criterion  \
# 0  Progressive, debilitating, severely disfigurin...
# 1  Progressive, debilitating, severely disfigurin...
# 2  Progressive, debilitating, severely disfigurin...
# 3  or more café-au-lait spots > 0.5 cm in prepube...
# 4      Adequate bone marrow, renal, hepatic function
#
#                            label                    term  ner_score  \
# 0             word_scores:cancer                   tumor      0.850
# 1             word_scores:cancer              tumor must      0.769
# 2          word_scores:treatment                 therapy      0.760
# 3  word_scores:clinical_variable      café-au-lait spots      0.845
# 4    word_scores:chronic_disease  renal hepatic function      0.807
#
#        concepts tree_numbers  nel_score       nct_id  \
# 0     Neoplasms          C04        1.0  NCT00030264
# 1           NaN          NaN        NaN  NCT00030264
# 2  Therapeutics          E02        1.0  NCT00030264
# 3           NaN          NaN        NaN  NCT00030264
# 4        Kidney  A05.810.453        1.0  NCT00030264
#
#                                                title  has_us_facility  \
# 0  Combination Chemotherapy in Treating Patients ...             True
# 1  Combination Chemotherapy in Treating Patients ...             True
# 2  Combination Chemotherapy in Treating Patients ...             True
# 3  Combination Chemotherapy in Treating Patients ...             True
# 4  Combination Chemotherapy in Treating Patients ...             True
#
#                                         conditions  \
# 0  Neurofibromatosis Type 1|Precancerous Condition
# 1  Neurofibromatosis Type 1|Precancerous Condition
# 2  Neurofibromatosis Type 1|Precancerous Condition
# 3  Neurofibromatosis Type 1|Precancerous Condition
# 4  Neurofibromatosis Type 1|Precancerous Condition
#
#                                 eligibility_criteria  start_date  \
# 0  Inclusion Criteria:\n\nProgressive, debilitati...  2001-02-28
# 1  Inclusion Criteria:\n\nProgressive, debilitati...  2001-02-28
# 2  Inclusion Criteria:\n\nProgressive, debilitati...  2001-02-28
# 3  Inclusion Criteria:\n\nProgressive, debilitati...  2001-02-28
# 4  Inclusion Criteria:\n\nProgressive, debilitati...  2001-02-28
#
#                           lead_sponsor  \
# 0  Children's Hospital of Philadelphia
# 1  Children's Hospital of Philadelphia
# 2  Children's Hospital of Philadelphia
# 3  Children's Hospital of Philadelphia
# 4  Children's Hospital of Philadelphia
#
#                                              summary overall_status    phase  \
# 0  RATIONALE: Drugs used in chemotherapy use diff...      Completed  Phase 2
# 1  RATIONALE: Drugs used in chemotherapy use diff...      Completed  Phase 2
# 2  RATIONALE: Drugs used in chemotherapy use diff...      Completed  Phase 2
# 3  RATIONALE: Drugs used in chemotherapy use diff...      Completed  Phase 2
# 4  RATIONALE: Drugs used in chemotherapy use diff...      Completed  Phase 2
#
#    enrollment enrollment_type      study_type  number_of_arms  \
# 0        23.0          Actual  Interventional             1.0
# 1        23.0          Actual  Interventional             1.0
# 2        23.0          Actual  Interventional             1.0
# 3        23.0          Actual  Interventional             1.0
# 4        23.0          Actual  Interventional             1.0
#
#    number_of_groups why_stopped has_dmc is_fda_regulated_drug  \
# 0               NaN         NaN    True                   NaN
# 1               NaN         NaN    True                   NaN
# 2               NaN         NaN    True                   NaN
# 3               NaN         NaN    True                   NaN
# 4               NaN         NaN    True                   NaN
#
#   is_fda_regulated_device is_unapproved_device  is_ppsd is_us_export  \
# 0                     NaN                  NaN      NaN          NaN
# 1                     NaN                  NaN      NaN          NaN
# 2                     NaN                  NaN      NaN          NaN
# 3                     NaN                  NaN      NaN          NaN
# 4                     NaN                  NaN      NaN          NaN
#
#   start_datetime  start_year mapped_phase  mapped_study_type  term_ben  \
# 0     2001-02-28      2001.0   d) Phase 2  a) Interventional     False
# 1     2001-02-28      2001.0   d) Phase 2  a) Interventional     False
# 2     2001-02-28      2001.0   d) Phase 2  a) Interventional     False
# 3     2001-02-28      2001.0   d) Phase 2  a) Interventional     False
# 4     2001-02-28      2001.0   d) Phase 2  a) Interventional     False
#
#    criterion_ben
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
label_table=ie_df.label.value_counts().reset_index()
label_table.columns=['label','count']
label_table
# Out:
#                                 label   count
# 0               word_scores:treatment  579695
# 1         word_scores:chronic_disease  346037
# 2                  word_scores:cancer  263611
# 3       word_scores:clinical_variable  242707
# 4                  word_scores:gender  105512
# 5               word_scores:pregnancy   65496
# 6   word_scores:contraception_consent   48455
# 7            word_scores:allergy_name   14190
# 8        word_scores:language_fluency    2718
# 9       word_scores:technology_access     945
# 10              word_scores:ethnicity      49

# %%
label_table=ie_df.groupby('label')['#nct_id'].nunique().reset_index()
label_table['label_clean']=label_table.label.apply(lambda x: x.split(':')[1])
label_table.columns=['Eligibility Criteria Label','# of Trials','label_clean']
label_table['total_trials']=ie_df['#nct_id'].nunique()
label_table['Percent of Trials']=label_table['# of Trials']/label_table['total_trials']
label_table.sort_values(by='# of Trials', ascending=False, inplace=True)
# display(label_table.style.format({'Percent of Trials': "{:.2%}"}))

# %%
## Setting figure & ax for plots
fig, ax = plt.subplots(figsize=(8.09,5))

## Setting plot to horizontal for easy viewing + setting title + display  
bar_plot = sns.barplot(y=label_table['Percent of Trials'], x=label_table['label_clean'], orient='v', ax=ax)
plt.xticks(rotation=90)
ax.set_ylabel('Proportion of Trials with Eligibility Criteria')
ax.set_xlabel('Eligibility Criteria Label')
ax.set_ylim([0, 1])
plt.title('Frequency of Eligibility Criteria')
plt.savefig("./visuals/ec_label_bars.png", bbox_inches='tight')
plt.show();

# %%
ie_df.term.nunique()
# Out:
# 268711

# %%
ie_df.term.value_counts().reset_index().term.sum()
# Out:
# 1668181

# %%
ie_df['term_stage']=ie_df['term'].str.contains("stage", na=False, case=False)

# %%
ie_df[ie_df.term_stage==True].iloc[1].criterion
# Out:
# 'Patients with pathologically confirmed prostate cancer Staged with Ⅲ-Ⅳ prostate cancer Aged from 18 to 65 years old Quality of life score (Karnofsky performance score) > 70 No distant metastasis No serious internal diseases may affect the treatment plan No previous history of prostate radiation therapy Patients must be able to understand and be willing to sign a written informed consent document'

# %%
ie_df['criterion_ben']=ie_df['criterion'].str.contains("constitutional neutropenia", na=False, case=False)

# %%
ie_df['criterion_ben'].value_counts().head()
# Out:
# False    1669415
# Name: criterion_ben, dtype: int64

# %%
ie_df['criteria_african']=ie_df['eligibility_criteria'].str.contains("african", na=False, case=False)

# %%
# NCT04381130
# afr_ncts[0]

# Glomerular Filtration Rate (GFR) is calculated using the MDRD formula:

# GFR = 175 x (Standardized SCr)-1.154 x (age)-0.203 x (0.742 if female) x (1.210 if African American)

# %%
# most seem to include race in title and as it's own eligiblity criterion

# %%
# NCT05050084
# afr_ncts[8]
# Creatinine clearance (CrCl) >= 30 mL/min estimated by Cockcroft-Gault equation (within 120 days prior to registration)

# For African American patients specifically whose renal function is not considered adequate by the formula above, an alternative formula that takes race into account (Chronic Kidney Disease Epidemiology Collaboration CKD-EPI formula) should be used for calculating the related estimated glomerular filtration rate (GFR) with a correction factor for African American race creatinine clearance for trial eligibility, where GFR >= 30 mL/min/1.73m^2 will be considered adequate

# %%
afr_ncts=ie_df[ie_df['criteria_african']==True]['#nct_id'].unique()

# %%
afr_ncts[11]
# Out:
# 'NCT05094466'

# %%
top_terms=ie_df.term.value_counts(normalize=True).head(10).reset_index()
top_terms.columns=['Term','Count']
top_terms=top_terms.style.format({'Count': "{:.2%}"})
display(top_terms)
# Out:
# <style  type="text/css" >
# </style><table id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Term</th>        <th class="col_heading level0 col1" >Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row0_col0" class="data row0 col0" >treatment</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row0_col1" class="data row0 col1" >2.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row1_col0" class="data row1 col0" >women</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row1_col1" class="data row1 col1" >1.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row2_col0" class="data row2 col0" >pregnant</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row2_col1" class="data row2 col1" >1.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row3_col0" class="data row3 col0" >bilirubin</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row3_col1" class="data row3 col1" >0.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row4_col0" class="data row4 col0" >female</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row4_col1" class="data row4 col1" >0.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row5_col0" class="data row5 col0" >chemotherapy</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row5_col1" class="data row5 col1" >0.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row6_col0" class="data row6 col0" >male female</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row6_col1" class="data row6 col1" >0.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row7_col0" class="data row7 col0" >therapy</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row7_col1" class="data row7 col1" >0.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row8_col0" class="data row8 col0" >malignancy</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row8_col1" class="data row8 col1" >0.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row9_col0" class="data row9 col0" >pregnancy</td>
#                         <td id="T_ef84e51e_fa9c_11ec_8700_faffc257f4f3row9_col1" class="data row9 col1" >0.54%</td>
#             </tr>
#     </tbody></table>

# %%
top_terms=ie_df.term.value_counts().head(10).reset_index()
top_terms.columns=['Term','Count']
top_terms['Percent of Total']=top_terms['Count']/ie_df.term.value_counts().reset_index().term.sum()
print(top_terms['Count'].sum())
display(top_terms.style.format({'Percent of Total': "{:.2%}"}))
# Out:
# 172673
# <style  type="text/css" >
# </style><table id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Term</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >Percent of Total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row0_col0" class="data row0 col0" >treatment</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row0_col1" class="data row0 col1" >42928</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row0_col2" class="data row0 col2" >2.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row1_col0" class="data row1 col0" >women</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row1_col1" class="data row1 col1" >28915</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row1_col2" class="data row1 col2" >1.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row2_col0" class="data row2 col0" >pregnant</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row2_col1" class="data row2 col1" >25249</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row2_col2" class="data row2 col2" >1.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row3_col0" class="data row3 col0" >bilirubin</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row3_col1" class="data row3 col1" >13935</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row3_col2" class="data row3 col2" >0.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row4_col0" class="data row4 col0" >female</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row4_col1" class="data row4 col1" >12696</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row4_col2" class="data row4 col2" >0.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row5_col0" class="data row5 col0" >chemotherapy</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row5_col1" class="data row5 col1" >10256</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row5_col2" class="data row5 col2" >0.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row6_col0" class="data row6 col0" >male female</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row6_col1" class="data row6 col1" >10116</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row6_col2" class="data row6 col2" >0.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row7_col0" class="data row7 col0" >therapy</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row7_col1" class="data row7 col1" >9968</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row7_col2" class="data row7 col2" >0.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row8_col0" class="data row8 col0" >malignancy</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row8_col1" class="data row8 col1" >9577</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row8_col2" class="data row8 col2" >0.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row9_col0" class="data row9 col0" >pregnancy</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row9_col1" class="data row9 col1" >9033</td>
#                         <td id="T_407cb71c_fa9f_11ec_874a_faffc257f4f3row9_col2" class="data row9 col2" >0.54%</td>
#             </tr>
#     </tbody></table>

# %%
all_terms=ie_df.term.value_counts().reset_index()
all_terms.columns=['Term','Count']
all_terms['Percent of Total']=all_terms['Count']/all_terms['Count'].sum()
all_terms['Cumulative Percentage']= all_terms['Percent of Total'].cumsum()
# print(top_terms['Count'].sum())
display(all_terms.head(10).style.format({'Percent of Total': "{:.2%}",'Cumulative Percentage': "{:.2%}"}))
# Out:
# <style  type="text/css" >
# </style><table id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Term</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >Percent of Total</th>        <th class="col_heading level0 col3" >Cumulative Percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row0_col0" class="data row0 col0" >treatment</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row0_col1" class="data row0 col1" >42928</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row0_col2" class="data row0 col2" >2.57%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row0_col3" class="data row0 col3" >2.57%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row1_col0" class="data row1 col0" >women</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row1_col1" class="data row1 col1" >28915</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row1_col2" class="data row1 col2" >1.73%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row1_col3" class="data row1 col3" >4.31%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row2_col0" class="data row2 col0" >pregnant</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row2_col1" class="data row2 col1" >25249</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row2_col2" class="data row2 col2" >1.51%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row2_col3" class="data row2 col3" >5.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row3_col0" class="data row3 col0" >bilirubin</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row3_col1" class="data row3 col1" >13935</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row3_col2" class="data row3 col2" >0.84%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row3_col3" class="data row3 col3" >6.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row4_col0" class="data row4 col0" >female</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row4_col1" class="data row4 col1" >12696</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row4_col2" class="data row4 col2" >0.76%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row4_col3" class="data row4 col3" >7.42%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row5_col0" class="data row5 col0" >chemotherapy</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row5_col1" class="data row5 col1" >10256</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row5_col2" class="data row5 col2" >0.61%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row5_col3" class="data row5 col3" >8.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row6_col0" class="data row6 col0" >male female</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row6_col1" class="data row6 col1" >10116</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row6_col2" class="data row6 col2" >0.61%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row6_col3" class="data row6 col3" >8.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row7_col0" class="data row7 col0" >therapy</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row7_col1" class="data row7 col1" >9968</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row7_col2" class="data row7 col2" >0.60%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row7_col3" class="data row7 col3" >9.24%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row8_col0" class="data row8 col0" >malignancy</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row8_col1" class="data row8 col1" >9577</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row8_col2" class="data row8 col2" >0.57%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row8_col3" class="data row8 col3" >9.81%</td>
#             </tr>
#             <tr>
#                         <th id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row9_col0" class="data row9 col0" >pregnancy</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row9_col1" class="data row9 col1" >9033</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row9_col2" class="data row9 col2" >0.54%</td>
#                         <td id="T_21b6c8a2_fafb_11ec_a054_faffc257f4f3row9_col3" class="data row9 col3" >10.35%</td>
#             </tr>
#     </tbody></table>

# %%
top_term_w_labels=ie_df[ie_df['term'].isin(top_terms['Term'].tolist())].groupby(['term','label']).size().reset_index().sort_values(by=['term',0], ascending=[False,False])
top_term_w_labels.columns=['Term','Label','Count']
top_term_w_labels
# Out:
#             Term                              Label  Count
# 13         women                 word_scores:gender  28915
# 12     treatment              word_scores:treatment  42927
# 11     treatment  word_scores:contraception_consent      1
# 10       therapy              word_scores:treatment   9949
# 9        therapy           word_scores:allergy_name     19
# 8       pregnant              word_scores:pregnancy  25249
# 7      pregnancy              word_scores:pregnancy   9033
# 5     malignancy                 word_scores:cancer   9576
# 6     malignancy              word_scores:treatment      1
# 4    male female                 word_scores:gender  10116
# 3         female                 word_scores:gender  12696
# 2   chemotherapy              word_scores:treatment  10255
# 1   chemotherapy  word_scores:contraception_consent      1
# 0      bilirubin      word_scores:clinical_variable  13935

# %%
all_terms['Top N Terms']=all_terms.index+1
all_terms.head()
# Out:
#         Term  Count  Percent of Total  Cumulative Percentage  ind  Top N Terms
# 0  treatment  42928          0.025733               0.025733    1            1
# 1      women  28915          0.017333               0.043067    2            2
# 2   pregnant  25249          0.015136               0.058202    3            3
# 3  bilirubin  13935          0.008353               0.066556    4            4
# 4     female  12696          0.007611               0.074166    5            5

# %%
all_terms['Count'].sum()
# Out:
# 1668181

# %%
cumulative_df=all_terms[['Top N Terms','Cumulative Percentage']]

# %%
cumulative_df.iloc[866:870]
# Out:
#      Top N Terms  Cumulative Percentage
# 866          867               0.499943
# 867          868               0.500055
# 868          869               0.500166
# 869          870               0.500278

# %%
cumulative_df[cumulative_df['Cumulative Percentage']<0.5].tail(2)
# Out:
#      Top N Terms  Cumulative Percentage
# 865          866               0.499832
# 866          867               0.499943

# %%
cumulative_df[cumulative_df['Cumulative Percentage']<0.25].tail(2)
# Out:
#     Top N Terms  Cumulative Percentage
# 61           62               0.247868
# 62           63               0.249411

# %%
plt.plot(cumulative_df['Top N Terms'], cumulative_df['Cumulative Percentage'])
plt.gca().set_yticklabels([f'{x:.0%}' for x in plt.gca().get_yticks()]) 
plt.gca().set(title='Prevalence of Top N Terms', ylabel='Cumulative % of Total Extracted Terms', xlabel='Top N Terms')
# plt.xscale('log')
ax = plt.gca()
# ax.set_xticks(cumulative_df['Top N Terms']) # note that with a log axis, you can't have x = 0 so that value isn't plotted.
plt.savefig("./visuals/cumulative_terms.png", bbox_inches='tight')

plt.show()

# %%
plt.plot(cumulative_df['Top N Terms'], cumulative_df['Cumulative Percentage'])
plt.gca().set_yticklabels([f'{x:.0%}' for x in plt.gca().get_yticks()]) 
plt.gca().set(title='Prevalence of Top N Terms', ylabel='Cumulative % of Total Extracted Terms', xlabel='Top N Terms (log scale)')
# plt.xscale('log')
ax = plt.gca()
# ax.set_xticks(cumulative_df['Top N Terms']) # note that with a log axis, you can't have x = 0 so that value isn't plotted.
ax.set_xscale('log')
ax.set_xticks([1,10,100,1000,10000, 100000])
ax.set_xticklabels(['1','10','100','1,000','10,000','100,000'])
ax.set_xlim([1,268711])
plt.savefig("./visuals/cumulative_terms_log.png", bbox_inches='tight')

plt.show()

# %%
cloud_terms=all_terms.iloc[:10000]

# %%
ct_dict={}
for i, r in all_terms.iterrows():
    ct_dict[r['Term']]=r['Count']

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', width = 300, height=300, margin=2, collocations=False)

wc.fit_words(ct_dict)
wc.to_file('./visuals/terms_cloud.png')

# plot the WordCloud image                      
plt.figure(figsize = (4, 4), facecolor = None)
plt.imshow(wc)

# %%
ie_df[ie_df.label=='word_scores:treatment'].term.value_counts().reset_index().head()
# Out:
#            index   term
# 0      treatment  42927
# 1   chemotherapy  10255
# 2        therapy   9949
# 3  major surgery   6589
# 4        surgery   6368

# %%
treatment_terms=ie_df[ie_df.label=='word_scores:treatment'].term.value_counts().reset_index()
treatment_terms.columns=['Term','Count']
treatment_terms['Percent of Total']=treatment_terms['Count']/treatment_terms['Count'].sum()
treatment_terms['Cumulative Percentage']= treatment_terms['Percent of Total'].cumsum()
# print(top_terms['Count'].sum())
display(treatment_terms.head(10).style.format({'Percent of Total': "{:.2%}",'Cumulative Percentage': "{:.2%}"}))
# Out:
# <style  type="text/css" >
# </style><table id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Term</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >Percent of Total</th>        <th class="col_heading level0 col3" >Cumulative Percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row0_col0" class="data row0 col0" >treatment</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row0_col1" class="data row0 col1" >42927</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row0_col2" class="data row0 col2" >7.41%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row0_col3" class="data row0 col3" >7.41%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row1_col0" class="data row1 col0" >chemotherapy</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row1_col1" class="data row1 col1" >10255</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row1_col2" class="data row1 col2" >1.77%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row1_col3" class="data row1 col3" >9.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row2_col0" class="data row2 col0" >therapy</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row2_col1" class="data row2 col1" >9949</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row2_col2" class="data row2 col2" >1.72%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row2_col3" class="data row2 col3" >10.89%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row3_col0" class="data row3 col0" >major surgery</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row3_col1" class="data row3 col1" >6589</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row3_col2" class="data row3 col2" >1.14%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row3_col3" class="data row3 col3" >12.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row4_col0" class="data row4 col0" >surgery</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row4_col1" class="data row4 col1" >6368</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row4_col2" class="data row4 col2" >1.10%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row4_col3" class="data row4 col3" >13.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row5_col0" class="data row5 col0" >prior therapy</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row5_col1" class="data row5 col1" >5050</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row5_col2" class="data row5 col2" >0.87%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row5_col3" class="data row5 col3" >14.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row6_col0" class="data row6 col0" >radiotherapy</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row6_col1" class="data row6 col1" >4820</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row6_col2" class="data row6 col2" >0.83%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row6_col3" class="data row6 col3" >14.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row7_col0" class="data row7 col0" >systemic treatment</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row7_col1" class="data row7 col1" >4715</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row7_col2" class="data row7 col2" >0.81%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row7_col3" class="data row7 col3" >15.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row8_col0" class="data row8 col0" >radiation therapy</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row8_col1" class="data row8 col1" >3683</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row8_col2" class="data row8 col2" >0.64%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row8_col3" class="data row8 col3" >16.28%</td>
#             </tr>
#             <tr>
#                         <th id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row9_col0" class="data row9 col0" >steroids</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row9_col1" class="data row9 col1" >3442</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row9_col2" class="data row9 col2" >0.59%</td>
#                         <td id="T_7098a5cc_fb0c_11ec_8b26_faffc257f4f3row9_col3" class="data row9 col3" >16.87%</td>
#             </tr>
#     </tbody></table>

# %%
# let's add wordcloud color based on relative amount of inclusion/exclusion criteria
# https://stackoverflow.com/questions/70883110/python-wordcloud-how-to-make-the-word-colour-based-on-a-data-column

# %%
tterms_dict={}
for i, r in treatment_terms.iterrows():
    tterms_dict[r['Term']]=r['Count']

# %%
import random

# %%
#https://vpsn-99.medium.com/sentiment-analysis-with-word-clouds-in-python-quick-and-dirty-leaning-8b957f645055
# https://github.com/Snailclimb/python/blob/master/PythonDemo/wordcloud/examples/colored_by_group.py

# %%
wc = WordCloud(background_color='white', width = 300, height=300, margin=2, collocations=False)
wc.fit_words(tterms_dict)
wc.to_file('./visuals/treatment_terms_cloud.png')

# plot the WordCloud image                      
plt.figure(figsize = (4, 4), facecolor = None)
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
plt.imshow(wc)

# %%
ie_df

# %%
ie_df.label.value_counts()
# Out:
# word_scores:treatment                579695
# word_scores:chronic_disease          346037
# word_scores:cancer                   263611
# word_scores:clinical_variable        242707
# word_scores:gender                   105512
# word_scores:pregnancy                 65496
# word_scores:contraception_consent     48455
# word_scores:allergy_name              14190
# word_scores:language_fluency           2718
# word_scores:technology_access           945
# word_scores:ethnicity                    49
# Name: label, dtype: int64

# %%
print(ie_df[(ie_df.label=='word_scores:contraception_consent')&(ie_df.term=='chemotherapy')].iloc[0].criterion)
# Out:
# Patients with histologically confirmed adenocarcinoma of biliary tract canacer (intrahepatic cholangiocarcinoma, extrahepatic cholangiocarcinoma, or gallbladder cancer) after curative intent R0 or R1 surgical resection Pathologic disease stage of T2-4, N0-2, M0 after surgery, according to AJCC 8th TNM staging Patients who complete resection (R0 or R1 resection) for biliary tract cancer within 12 weeks of the adjuvant chemotherapy No distant metastasis ECOG performance sstatus score of 0 or 1 Age 19 years or older Adequate bone marrow fuction (neutrophils ≥ 1.5 x 109/L, platelets ≥ 100 x 109/L and hemoglobin ≥9 g/dL) Adequate liver function (total bilirubin < 1.5 fold the upper limit of normal of the study site (ULN), alanine aminotransferase (ALT) or aspartate aminotransferase (AST) < 5.0 x ULN) Adequate kidney function (Creatinine < 1.5 x ULN) Unresolved systemic active infection (except for chronic viral hepatitis taking antiviral drugs) Not receiving other drugs for clinical trials or chemotherapy within 30 days prior to randomization A female participant who is not post-menopausal or amenorrhea less than 12 consecutive months without specific reasons is eligible to participate if she is not pregnant, confirmed by serum tests within 7 days before the initiation of chemotherapy The participants provide written informed consent for the study. No prior chemotherapy for biliary tract cancer Participants of childbearing potential must agree to use an adequate method of contraception for the course of the study throught 120 days after the last dose of chemotherapy (oral contraceptives or mechanical contraception such as intrauterine devices or contraceptive barriers and etc). Childbearing potential female is who is not post-menopausal or amenorrhea less than 12 consecutive months without specific reasons

# %%
# ie_df[ie_df['#nct_id']=='NCT04401709'].tail(30)

# %%
cfg=pd.read_csv(path+"/extract/extracted_data/cfg_parsed_clinical_trials.tsv", sep='\t')
# ie_df=ie.merge(onc_trials, how='inner', left_on='#nct_id', right_on='nct_id').iloc[:, 1:36]

# %%
cfg.head()
# Out:
#        #nct_id eligibility_type variable_type  criterion_index  \
# 0  NCT00000658        inclusion     numerical                0
# 1  NCT00000694        exclusion       ordinal                0
# 2  NCT00000694        exclusion     numerical                1
# 3  NCT00000694        exclusion       ordinal                2
# 4  NCT00000694        exclusion     numerical                3
#
#                                            criterion  \
# 0  Diagnosis of HIV seropositivity and non-Hodgki...
# 1  Prior or concurrent opportunistic infection or...
# 2  Prior or concurrent opportunistic infection or...
# 3  Prior or concurrent opportunistic infection or...
# 4  Prior or concurrent opportunistic infection or...
#
#                          question  \
# 0                How old are you?
# 1        What is your NYHA class?
# 2  What is your body temperature?
# 3        What is your NYHA class?
# 4  What is your body temperature?
#
#                                             relation
# 0  {"id":"200","name":"age","unit":"year","lower"...
# 1  {"id":"102","name":"nyha","value":["1","2"],"v...
# 2  {"id":"207","name":"body_temperature","upper":...
# 3  {"id":"102","name":"nyha","value":["1","2"],"v...
# 4  {"id":"207","name":"body_temperature","upper":...

# %%
cfg.shape
# Out:
# (227517, 7)

# %%
cfg.eligibility_type.value_counts()
# Out:
# inclusion    184810
# exclusion     42707
# Name: eligibility_type, dtype: int64

# %%
cfg.question.value_counts(normalize=True).head()
# Out:
# How old are you?                         0.120510
# What are your ALT and AST values?        0.104506
# What is your ECOG performance status?    0.094556
# What is your total bilirubin level?      0.090002
# What is your platelet count?             0.082543
# Name: question, dtype: float64

# %%
cfg[cfg.question=='How old are you?'].iloc[0].relation
# Out:
# '{"id":"200","name":"age","unit":"year","lower":{"incl":true,"value":"12"},"upper":{"incl":true,"value":"18"},"variableType":"numerical","score":0.5833333333333333}'

# %%
cfg[cfg.question=='What are your ALT and AST values?'].iloc[0].relation
# Out:
# '{"id":"411","name":"ast","unit":"uln","upper":{"incl":true,"value":"3"},"variableType":"numerical","score":1}'

# %%
import json

# %%
cfg["relation_dict"] = cfg["relation"].apply(lambda x: json.loads(x))

# %%
cfg.head(2)
# Out:
#        #nct_id eligibility_type variable_type  criterion_index  \
# 0  NCT00000658        inclusion     numerical                0
# 1  NCT00000694        exclusion       ordinal                0
#
#                                            criterion  \
# 0  Diagnosis of HIV seropositivity and non-Hodgki...
# 1  Prior or concurrent opportunistic infection or...
#
#                    question  \
# 0          How old are you?
# 1  What is your NYHA class?
#
#                                             relation  \
# 0  {"id":"200","name":"age","unit":"year","lower"...
# 1  {"id":"102","name":"nyha","value":["1","2"],"v...
#
#                                        relation_dict
# 0  {'id': '200', 'name': 'age', 'unit': 'year', '...
# 1  {'id': '102', 'name': 'nyha', 'value': ['1', '...

# %%
from collections import defaultdict

# %%
relation_count=defaultdict(int)

# %%
for i, r in cfg.iterrows():
    rk=r.relation_dict.keys()
    for key in rk:
        try:
            relation_count[key] += 1
        except KeyError:
            relation_count[key] = 1

# %%
cfg.iloc[0].relation_dict.keys()
# Out:
# dict_keys(['id', 'name', 'unit', 'lower', 'upper', 'variableType', 'score'])

# %%
cfg.shape
# Out:
# (227517, 8)

# %%
relation_count
# Out:
# defaultdict(int,
#             {'id': 227517,
#              'name': 227517,
#              'unit': 174545,
#              'lower': 120435,
#              'upper': 91500,
#              'variableType': 227517,
#              'score': 227517,
#              'value': 27766})

# %%
for key in relation_count.keys():
    cfg[key]=cfg['relation_dict'].apply(lambda x: x.get(key))

# %%
cfg.head(2)
# Out:
#        #nct_id eligibility_type variable_type  criterion_index  \
# 0  NCT00000658        inclusion     numerical                0
# 1  NCT00000694        exclusion       ordinal                0
#
#                                            criterion  \
# 0  Diagnosis of HIV seropositivity and non-Hodgki...
# 1  Prior or concurrent opportunistic infection or...
#
#                    question  \
# 0          How old are you?
# 1  What is your NYHA class?
#
#                                             relation  \
# 0  {"id":"200","name":"age","unit":"year","lower"...
# 1  {"id":"102","name":"nyha","value":["1","2"],"v...
#
#                                        relation_dict   id  name  unit  \
# 0  {'id': '200', 'name': 'age', 'unit': 'year', '...  200   age  year
# 1  {'id': '102', 'name': 'nyha', 'value': ['1', '...  102  nyha  None
#
#                            lower                          upper variableType  \
# 0  {'incl': True, 'value': '12'}  {'incl': True, 'value': '18'}    numerical
# 1                           None                           None      ordinal
#
#       score   value
# 0  0.583333    None
# 1  1.000000  [1, 2]

# %%
cfg['lower_incl']=cfg['lower'].apply(lambda x: x.get('incl') if pd.notnull(x) else x)
cfg['lower_value']=cfg['lower'].apply(lambda x: x.get('value') if pd.notnull(x) else x)

cfg['upper_incl']=cfg['upper'].apply(lambda x: x.get('incl') if pd.notnull(x) else x)
cfg['upper_value']=cfg['upper'].apply(lambda x: x.get('value') if pd.notnull(x) else x)

# %%
cfg.head(2)
# Out:
#        #nct_id eligibility_type variable_type  criterion_index  \
# 0  NCT00000658        inclusion     numerical                0
# 1  NCT00000694        exclusion       ordinal                0
#
#                                            criterion  \
# 0  Diagnosis of HIV seropositivity and non-Hodgki...
# 1  Prior or concurrent opportunistic infection or...
#
#                    question  \
# 0          How old are you?
# 1  What is your NYHA class?
#
#                                             relation  \
# 0  {"id":"200","name":"age","unit":"year","lower"...
# 1  {"id":"102","name":"nyha","value":["1","2"],"v...
#
#                                        relation_dict   id  name  unit  \
# 0  {'id': '200', 'name': 'age', 'unit': 'year', '...  200   age  year
# 1  {'id': '102', 'name': 'nyha', 'value': ['1', '...  102  nyha  None
#
#                            lower                          upper variableType  \
# 0  {'incl': True, 'value': '12'}  {'incl': True, 'value': '18'}    numerical
# 1                           None                           None      ordinal
#
#       score   value lower_incl lower_value upper_incl upper_value
# 0  0.583333    None       True          12       True          18
# 1  1.000000  [1, 2]       None        None       None        None

# %%
cfg.name.value_counts(normalize=True).head()
# Out:
# age                      0.120510
# ecog                     0.094556
# total_bilirubin_level    0.090002
# platelet_count           0.082543
# anc                      0.071819
# Name: name, dtype: float64

# %%
cfg[cfg.name=='anc']['#nct_id'].nunique()/cfg['#nct_id'].nunique()
# Out:
# 0.29701233543324906

# %%
cfg[cfg.name=='anc']['#nct_id'].nunique()
# Out:
# 15747

# %%
# Examples of exclusion criteria that enable enrollment of a more diverse and inclusive study population:

# Glomerular filtration rate < {XX} mL/min/1.73 m2 as calculated through use of the Chronic Kidney Disease Epidemiology Collaboration equation

# ANC < 1.5 × 10^9/L (1500/μL) for patients of non-African descent or < 1.3 × 10^9/L (1300/μL) for patients of African descent

# ANC < 1.5 × 109/L (1500/μL) with one exception:
# Patients with benign ethnic neutropenia: ANC << 1.3 × 109/L (1300/μL)
# *Benign ethnic neutropenia (BEN; also called constitutional neutropenia) is an inherited cause of mild/moderate neutropenia that is not associated with any increased risk for infections or other clinical manifestations (Atallah-Yunes, et al 2019, doi: 10.1016/j.blre.2019.06.003). BEN is referred to as ethnic neutropenia because of its increased prevalence in people of African descent and other specific ethnic groups.

# %%
anc=cfg[cfg.name=='anc']
anc.head(1)
# Out:
#        #nct_id eligibility_type variable_type  criterion_index  \
# 7  NCT00000954        inclusion     numerical                0
#
#                                            criterion  \
# 7  Chemoprophylaxis for candidiasis, MAC, and her...
#
#                                   question  \
# 7  What is your absolute neutrophil count?
#
#                                             relation  \
# 7  {"id":"408","name":"anc","upper":{"incl":false...
#
#                                        relation_dict   id name  unit lower  \
# 7  {'id': '408', 'name': 'anc', 'upper': {'incl':...  408  anc  None  None
#
#                               upper variableType     score value lower_incl  \
# 7  {'incl': False, 'value': '1000'}    numerical  0.710526  None       None
#
#   lower_value upper_incl upper_value
# 7        None      False        1000

# %%
anc.lower_value.value_counts(normalize=True).head(10)
# Out:
# 1500     0.380392
# 1.5e9    0.267577
# 1000     0.139924
# 1.0e9    0.037501
# 1.5      0.020973
# 500      0.017592
# 750      0.012584
# 2000     0.009892
# 2.0e9    0.008765
# 1e9      0.008702
# Name: lower_value, dtype: float64

# %%
anc.upper_value.value_counts(normalize=True).head(10)
# Out:
# 1000     0.160600
# 1500     0.113490
# 500      0.102784
# 1.5e9    0.100642
# 1        0.057816
# 2        0.049251
# 1.0e9    0.047109
# 1.5      0.032120
# 0.5e9    0.029979
# 1800     0.017131
# Name: upper_value, dtype: float64

# %%
cfg.iloc[0].relation_dict
# Out:
# {'id': '200',
#  'name': 'age',
#  'unit': 'year',
#  'lower': {'incl': True, 'value': '12'},
#  'upper': {'incl': True, 'value': '18'},
#  'variableType': 'numerical',
#  'score': 0.5833333333333333}

# %%
# Out:
# 'age'

# %%
pd.concat([df, df.the_column.apply(json.loads).apply(pd.Series)], axis=1)

# %%
cfg[cfg.question=='What is your ECOG performance status?'].iloc[0].relation
# Out:
# '{"id":"100","name":"ecog","value":["2"],"variableType":"ordinal","score":0.8666666666666667}'

# %%
cfg[cfg['#nct_id']=='NCT00001251']
# Out:
#         #nct_id eligibility_type variable_type  criterion_index  \
# 31  NCT00001251        inclusion     numerical                0
# 32  NCT00001251        inclusion       ordinal                1
# 33  NCT00001251        inclusion     numerical                2
#
#                                             criterion  \
# 31  All patients over 3 years of age with meningea...
# 32  Patients must have a life expectancy of at lea...
# 33  Patients must have a life expectancy of at lea...
#
#                                  question  \
# 31                       How old are you?
# 32  What is your ECOG performance status?
# 33          What is your life expectancy?
#
#                                              relation
# 31  {"id":"200","name":"age","unit":"year","lower"...
# 32  {"id":"100","name":"ecog","value":["2"],"varia...
# 33  {"id":"206","name":"life_expectancy","unit":"w...

# %%
# Test GPT-3 for ECOG
cfg[cfg.question=='What is your ECOG performance status?'].iloc[0].criterion
# Out:
# 'Patients must have a life expectancy of at least 8 weeks and an ECOG performance status of 2 or better. Patients who are unable to walk because of paralysis, but who are up in a wheelchair will be considered ambulatory for the purposes of the performance score'

# %%
cfg[cfg.question=='What is your ECOG performance status?'].iloc[1].criterion
# Out:
# 'Performance status ECOG of 0-3'

# %%
cfg[cfg.question=='What is your ECOG performance status?'].iloc[2].criterion
# Out:
# 'Performance status of less than or equal to ECOG 2'

# %%
cfg[cfg.question=='What is your ECOG performance status?'].iloc[3].criterion
# Out:
# 'Karnofsky performance status of greater than 70% (ECOG 0 or 1)'

# %%
import os
import openai

# %%
openai.api_key = "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"

# %%
gpt3_prompt="""
Input:
Patients must have a life expectancy of at least 8 weeks and an ECOG performance status of 2 or better. Patients who are unable to walk because of paralysis, but who are up in a wheelchair will be considered ambulatory for the purposes of the performance score

Output:
ECOG 0
ECOG 1
ECOG 2


Input:
Performance status ECOG of 0-3

Output:
ECOG 0
ECOG 1
ECOG 2
ECOG 3


Input:
Performance status of less than or equal to ECOG 2

Output:
ECOG 0
ECOG 1
ECOG 2


Input:
Karnofsky performance status of greater than 70% (ECOG 0 or 1)

Output:
ECOG 0
ECOG 1


Input:
"""

# %%
row=4
row_prompt=cfg[cfg.question=='What is your ECOG performance status?'].iloc[row].criterion

# %%
row_prompt
# Out:
# 'Patients must have an ECOG performance status of 0, 1 or 2 (i.e. an activity level wherein the patient is out of bed greater than 50% of the day or more) and a life expectancy of at least 8 weeks'

# %%
prmpt=gpt3_prompt+row_prompt+"""\n
Output:\n"""

# %%
print(prmpt )
# Out:
# Input:
# Patients must have a life expectancy of at least 8 weeks and an ECOG performance status of 2 or better. Patients who are unable to walk because of paralysis, but who are up in a wheelchair will be considered ambulatory for the purposes of the performance score
#
# Output:
# ECOG 0
# ECOG 1
# ECOG 2
#
#
# Input:
# Performance status ECOG of 0-3
#
# Output:
# ECOG 0
# ECOG 1
# ECOG 2
# ECOG 3
#
#
# Input:
# Performance status of less than or equal to ECOG 2
#
# Output:
# ECOG 0
# ECOG 1
# ECOG 2
#
#
# Input:
# Karnofsky performance status of greater than 70% (ECOG 0 or 1)
#
# Output:
# ECOG 0
# ECOG 1
#
#
# Input:
# Patients must have an ECOG performance status of 0, 1 or 2 (i.e. an activity level wherein the patient is out of bed greater than 50% of the day or more) and a life expectancy of at least 8 weeks
#
# Output:

# %%
gpt3_parameters={
'model':"text-davinci-002",
'temperature':0,
'max_tokens':300,
'top_p':1,
'frequency_penalty':0.5,
'presence_penalty':0
}

# %%
response = openai.Completion.create(
  model=gpt3_parameters.get('model'),
  prompt=prmpt,
  temperature=gpt3_parameters.get('temperature'),
  max_tokens=gpt3_parameters.get('max_tokens'),
  top_p=gpt3_parameters.get('top_p'),
  frequency_penalty=gpt3_parameters.get('frequency_penalty'),
  presence_penalty=gpt3_parameters.get('presence_penalty')
)

# %%
print(response.choices[0].text)
# Out:
# ECOG 0
# ECOG 1
# ECOG 2

# %%
row=6
row_prompt=cfg[cfg.question=='What is your ECOG performance status?'].iloc[row].criterion
row_prompt
# Out:
# 'Ages 10 to 55 years. Chronic myelogenous leukemia, any of these categories: chronic phase, accelerated phase of blast transformation. Acute lymphoblastic leukemia, any of these categories: Adults (greater than 18 years) in first remission with high risk features (presenting leukocyte count greater than 100,000 per cu mm, Karyotypes t9;22, t4, t19, t11, biphenotypic leukemia). All second remissions, primary induction failure, partially responding or untreated relapse. Acute myelogenous leukemia (AML): AML in first remission Except AML with good risk karyotypes: AML M3 (t15;17), AML M4Eo (inv 16), AML t(8;21). All AML in second or subsequent remission, primary induction failure and resistant relapse. Myelodysplastic syndromes, any of these categories: refractory anemia with excess of blasts, transformation to acute leukemia, chronic myelomonocytic leukemia. Multiple myeloma following initial disease control with chemotherapy. Chronic lymphocytic leukemia (CLL) and prolymphocytic leukemia, in remission or partial remission following fludarabine treatment. Richter transformation of CLL. No major organ dysfunction precluding transplantation. DLCO greater than 65 percent predicted. Left ventricular ejection fraction: greater than 40 percent predicted. ECOG performance status of 0 or 1. Informed consent given. Informed consent from both parents for minors. Women of childbearing age with a negative pregnancy test may participate'

# %%
prmpt=gpt3_prompt+row_prompt+"""\n
Output:\n"""

response = openai.Completion.create(
  model=gpt3_parameters.get('model'),
  prompt=prmpt,
  temperature=gpt3_parameters.get('temperature'),
  max_tokens=gpt3_parameters.get('max_tokens'),
  top_p=gpt3_parameters.get('top_p'),
  frequency_penalty=gpt3_parameters.get('frequency_penalty'),
  presence_penalty=gpt3_parameters.get('presence_penalty')
)

print(response.choices[0].text)
# Out:
# ECOG 0
# ECOG 1

# %%
row=8
row_prompt=cfg[cfg.question=='What is your ECOG performance status?'].iloc[row].criterion
row_prompt
# Out:
# 'Patients must be ECOG performance status of less than or equal to 2'

# %%
prmpt=gpt3_prompt+row_prompt+"""\n
Output:\n"""

response = openai.Completion.create(
  model=gpt3_parameters.get('model'),
  prompt=prmpt,
  temperature=gpt3_parameters.get('temperature'),
  max_tokens=gpt3_parameters.get('max_tokens'),
  top_p=gpt3_parameters.get('top_p'),
  frequency_penalty=gpt3_parameters.get('frequency_penalty'),
  presence_penalty=gpt3_parameters.get('presence_penalty')
)

print(response.choices[0].text)
# Out:
# ECOG 0
# ECOG 1
# ECOG 2

# %%
row=14
row_prompt=cfg[cfg.question=='What is your ECOG performance status?'].iloc[row].criterion
row_prompt
# Out:
# 'ECOG performance status of 3 or more'

# %%
prmpt=gpt3_prompt+row_prompt+"""\n
Output:\n"""

response = openai.Completion.create(
  model=gpt3_parameters.get('model'),
  prompt=prmpt,
  temperature=gpt3_parameters.get('temperature'),
  max_tokens=gpt3_parameters.get('max_tokens'),
  top_p=gpt3_parameters.get('top_p'),
  frequency_penalty=gpt3_parameters.get('frequency_penalty'),
  presence_penalty=gpt3_parameters.get('presence_penalty')
)

print(response.choices[0].text)
# Out:
# ECOG 3
